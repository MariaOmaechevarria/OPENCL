# %% [markdown]
# EXPERIMENTO:Comparar kernels para distintos filtros con un local size fijado
#
# OBJETIVO: Determinar el mejor kernel
#
# OUTPUT: Para cada filtro una tabla con los tiempos de ejecucion y un grafico
#
# DONDE: EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS UNA CARPETA PARA CADA TAMAÑO DE FILTRO

# %% [markdown]
# Instalar pyopencl

# %%
pip install pyopencl
# Out:
# Requirement already satisfied: pyopencl in c:\users\eevee\anaconda3\lib\site-packages (2024.2.7)
# Requirement already satisfied: numpy in c:\users\eevee\anaconda3\lib\site-packages (from pyopencl) (1.26.4)
# Requirement already satisfied: platformdirs>=2.2.0 in c:\users\eevee\anaconda3\lib\site-packages (from pyopencl) (3.10.0)
# Requirement already satisfied: pytools>=2024.1.5 in c:\users\eevee\anaconda3\lib\site-packages (from pyopencl) (2024.1.14)
# Requirement already satisfied: typing-extensions>=4 in c:\users\eevee\anaconda3\lib\site-packages (from pytools>=2024.1.5->pyopencl) (4.11.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# LIBRERIAS

# %%
import pyopencl as cl
import numpy as np
import pandas as pd
import os
from PIL import Image, ImageFilter
from collections import defaultdict
# Out:
# c:\Users\Eevee\anaconda3\Lib\site-packages\pytools\persistent_dict.py:63: RecommendedHashNotFoundWarning: Unable to import recommended hash 'siphash24.siphash13', falling back to 'hashlib.sha256'. Run 'python3 -m pip install siphash24' to install the recommended hash.
#   warn("Unable to import recommended hash 'siphash24.siphash13', "

# %% [markdown]
# IMPORTAR ARCHIVOS Y FUNCIONES

# %%
import funciones_ejecutar_kernel_filtros as ff
import kernels_filtros_imagenes as kernel
import filtros as f
import funciones_experimento_filtros as ex

# %% [markdown]
# VALORES A ADAPTAR SEGUN EL DISPOSITIVO

# %%
'''
 # Datos GPU
compute_units = 96
processing_elements = 8

#RUTA DE ARCHIVOS
path=path="C:/Users/maria/OneDrive/OPENCL/RESULTADOS_PORTATIL" 

'''


path="C:/Users/Eevee"
# Datos GPU
compute_units = 82   #Adaptar según la GPU
processing_elements = 128

# %%
def aplicar_todos_kernels(filtros,titulo):
    # Parámetros de los kernels y funciones
    kernels = [
        kernel.kernel_filter_color,
        kernel.kernel_filter_color_local_ineficiente,
        kernel.kernel_filter_color_local_hebra_maestra,
        kernel.kernel_filter_color_local_organizado,
        kernel.kernel_filter_color_local_organizado_junto,
        kernel.kernel_filter_color_rectangular,
        kernel.kernel_filter_color_local_rectangular
    ]
    kernels_names = [
        "kernel_filter_color",
        "kernel_filter_color_local_ineficiente",
        "kernel_filter_color_local_hebra_maestra",
        "kernel_filter_color_local_organizado",
        "kernel_filter_color_local_organizado_junto",
         "kernel_filter_color_rectangular",
        "kernel_filter_color_local_rectangular"
    ]
    funciones = [
        ff.aplicar_filtro_color,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_color_dividido,
        ff.aplicar_filtro_local_dividido
    ]
    
    device_type =  cl.device_type.GPU 
    local_size = (8,8)  # Cambia esto al tamaño local que desees

    # Lista de paths de imágenes
    lista_paths = [
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen64x64.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen128x128.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen640x480.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen800x600.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen720x1280.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen1920x1080.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen2160x3840.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen8000x6000.jpg")]

    # Directorio base para guardar los gráficos
    base_path = os.path.join(path, "OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/")
    base_save_dir = os.path.join(base_path, titulo)

    # Ejecutar el experimento
    resultados_finales = ex.experimento_kernels(
        lista_paths,
        filtros,
        kernels,
        kernels_names,
        funciones,
        device_type,
        local_size,
        base_save_dir
    )

def aplicar_filtros():
    #Aplicar filtro 3x3
    aplicar_todos_kernels([f.filtro_mean,f.filtro_mean,f.filtro_mean,f.filtro_mean,f.filtro_mean,[f.filtro_meanX,f.filtro_meanY],[f.filtro_meanX,f.filtro_meanY],],"FILTRO3X3/")
    #Aplicar filtro 5x5
    aplicar_todos_kernels([f.filtro_mean5x5,[f.filtro_mean5X5X,f.filtro_mean5X5Y],f.filtro_mean5x5,f.filtro_mean5x5,f.filtro_mean5x5,f.filtro_mean5x5,[f.filtro_mean5X5X,f.filtro_mean5X5Y]],"FILTRO5X5/")
    #Aplicar filtro 7x7
    aplicar_todos_kernels([f.filtro_mean7x7,[f.filtro_mean7x7X,f.filtro_mean7x7Y],f.filtro_mean7x7,f.filtro_mean7x7,f.filtro_mean7x7,f.filtro_mean5x5,[f.filtro_mean7x7X,f.filtro_mean7x7Y]],"FILTRO7X7/")
    #Aplicar filtro 9x9
    aplicar_todos_kernels([f.filtro_mean9x9,[f.filtro_mean9x9X,f.filtro_mean9x9Y],f.filtro_mean9x9,f.filtro_mean9x9,f.filtro_mean9x9,f.filtro_mean9x9,[f.filtro_mean9x9X,f.filtro_mean9x9Y]],"FILTRO9X9/")
    #Aplicar filtro 16x16
    aplicar_todos_kernels([f.filtro_mean16x16,[f.filtro_mean16x16X,f.filtro_mean16x16Y],f.filtro_mean16x16,f.filtro_mean16x16,f.filtro_mean16x16,f.filtro_mean16x16,[f.filtro_mean16x16X,f.filtro_mean16x16Y]],"FILTRO16X16/")

# %%
aplicar_filtros()
# Out:
# c:\Users\Eevee\anaconda3\Lib\site-packages\pyopencl\__init__.py:519: CompilerWarning: Non-empty compiler output encountered. Set the environment variable PYOPENCL_COMPILER_OUTPUT=1 to see more.
#   lambda: self._prg.build(options_bytes, devices),
# c:\Users\Eevee\anaconda3\Lib\site-packages\pyopencl\__init__.py:519: CompilerWarning: Non-empty compiler output encountered. Set the environment variable PYOPENCL_COMPILER_OUTPUT=1 to see more.
#   lambda: self._prg.build(options_bytes, devices),
# c:\Users\Eevee\anaconda3\Lib\site-packages\pyopencl\__init__.py:519: CompilerWarning: Non-empty compiler output encountered. Set the environment variable PYOPENCL_COMPILER_OUTPUT=1 to see more.
#   lambda: self._prg.build(options_bytes, devices),
# c:\Users\Eevee\anaconda3\Lib\site-packages\pyopencl\__init__.py:519: CompilerWarning: Non-empty compiler output encountered. Set the environment variable PYOPENCL_COMPILER_OUTPUT=1 to see more.
#   lambda: self._prg.build(options_bytes, devices),
# c:\Users\Eevee\anaconda3\Lib\site-packages\pyopencl\__init__.py:519: CompilerWarning: Non-empty compiler output encountered. Set the environment variable PYOPENCL_COMPILER_OUTPUT=1 to see more.
#   lambda: self._prg.build(options_bytes, devices),
# DataFrames guardados y formateados en Excel en C:/Users/Eevee\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO3X3/kernels\resultados.xlsx
# Gráfico guardado en C:/Users/Eevee\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO3X3/KERNELS_tiempos_ejecucion.png
# Error al procesar imagen64x64.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen128x128.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen640x480.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen800x600.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen720x1280.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen1920x1080.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen2160x3840.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen8000x6000.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen64x64.jpg: too many values to unpack (expected 2)
# Error al procesar imagen128x128.jpg: too many values to unpack (expected 2)
# Error al procesar imagen640x480.jpg: too many values to unpack (expected 2)
# Error al procesar imagen800x600.jpg: too many values to unpack (expected 2)
# Error al procesar imagen720x1280.jpg: too many values to unpack (expected 2)
# Error al procesar imagen1920x1080.jpg: too many values to unpack (expected 2)
# Error al procesar imagen2160x3840.jpg: too many values to unpack (expected 2)
# Error al procesar imagen8000x6000.jpg: too many values to unpack (expected 2)
# DataFrames guardados y formateados en Excel en C:/Users/Eevee\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO5X5/kernels\resultados.xlsx
# Gráfico guardado en C:/Users/Eevee\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO5X5/KERNELS_tiempos_ejecucion.png
# Error al procesar imagen64x64.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen128x128.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen640x480.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen800x600.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen720x1280.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen1920x1080.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen2160x3840.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen8000x6000.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen64x64.jpg: too many values to unpack (expected 2)
# Error al procesar imagen128x128.jpg: too many values to unpack (expected 2)
# Error al procesar imagen640x480.jpg: too many values to unpack (expected 2)
# Error al procesar imagen800x600.jpg: too many values to unpack (expected 2)
# Error al procesar imagen720x1280.jpg: too many values to unpack (expected 2)
# Error al procesar imagen1920x1080.jpg: too many values to unpack (expected 2)
# Error al procesar imagen2160x3840.jpg: too many values to unpack (expected 2)
# Error al procesar imagen8000x6000.jpg: too many values to unpack (expected 2)
# DataFrames guardados y formateados en Excel en C:/Users/Eevee\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO7X7/kernels\resultados.xlsx
# Gráfico guardado en C:/Users/Eevee\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO7X7/KERNELS_tiempos_ejecucion.png
# Error al procesar imagen64x64.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen128x128.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen640x480.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen800x600.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen720x1280.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen1920x1080.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen2160x3840.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen8000x6000.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen64x64.jpg: too many values to unpack (expected 2)
# Error al procesar imagen128x128.jpg: too many values to unpack (expected 2)
# Error al procesar imagen640x480.jpg: too many values to unpack (expected 2)
# Error al procesar imagen800x600.jpg: too many values to unpack (expected 2)
# Error al procesar imagen720x1280.jpg: too many values to unpack (expected 2)
# Error al procesar imagen1920x1080.jpg: too many values to unpack (expected 2)
# Error al procesar imagen2160x3840.jpg: too many values to unpack (expected 2)
# Error al procesar imagen8000x6000.jpg: too many values to unpack (expected 2)
# DataFrames guardados y formateados en Excel en C:/Users/Eevee\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO9X9/kernels\resultados.xlsx
# Gráfico guardado en C:/Users/Eevee\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO9X9/KERNELS_tiempos_ejecucion.png
# Error al procesar imagen64x64.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen128x128.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen640x480.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen800x600.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen720x1280.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen1920x1080.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen2160x3840.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen8000x6000.jpg: a bytes-like object is required, not 'tuple'
# Error al procesar imagen64x64.jpg: too many values to unpack (expected 2)
# Error al procesar imagen128x128.jpg: too many values to unpack (expected 2)
# Error al procesar imagen640x480.jpg: too many values to unpack (expected 2)
# Error al procesar imagen800x600.jpg: too many values to unpack (expected 2)
# Error al procesar imagen720x1280.jpg: too many values to unpack (expected 2)
# Error al procesar imagen1920x1080.jpg: too many values to unpack (expected 2)
# Error al procesar imagen2160x3840.jpg: too many values to unpack (expected 2)
# Error al procesar imagen8000x6000.jpg: too many values to unpack (expected 2)
# DataFrames guardados y formateados en Excel en C:/Users/Eevee\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO16X16/kernels\resultados.xlsx
# Gráfico guardado en C:/Users/Eevee\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO16X16/KERNELS_tiempos_ejecucion.png

# %% [markdown]
# FUNCIONES A APLICAR, UNA POR CADA TAMAÑO DE FILTRO

# %%
def aplicar_todos_kernels(filtros,titulo):
    # Parámetros de los kernels y funciones
    kernels = [
        kernel.kernel_filter_color,
        kernel.kernel_filter_color_local_ineficiente,
        kernel.kernel_filter_color_local_hebra_maestra,
        kernel.kernel_filter_color_local_organizado,
        kernel.kernel_filter_color_local_organizado_junto,
        kernel.kernel_filter_color_rectangular,
        kernel.kernel_filter_color_local_rectangular
    ]
    kernels_names = [
        "kernel_filter_color",
        "kernel_filter_color_local_ineficiente",
        "kernel_filter_color_local_hebra_maestra",
        "kernel_filter_color_local_organizado",
        "kernel_filter_color_local_organizado_junto",
         "kernel_filter_color_rectangular",
        "kernel_filter_color_local_rectangular"
    ]
    funciones = [
        ff.aplicar_filtro_color,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_color_dividido,
        ff.aplicar_filtro_local_dividido
    ]
    
    device_type =  cl.device_type.GPU 
    local_size = (8,8)  # Cambia esto al tamaño local que desees

    # Lista de paths de imágenes
    lista_paths = [
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen64x64.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen128x128.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen640x480.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen800x600.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen720x1280.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen1920x1080.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen2160x3840.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen8000x6000.jpg")]

    # Directorio base para guardar los gráficos
    base_path = os.path.join(path, "OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/")
    base_save_dir = os.path.join(base_path, titulo)

    # Ejecutar el experimento
    resultados_finales = ex.experimento_kernels(
        lista_paths,
        filtros,
        kernels,
        kernels_names,
        funciones,
        device_type,
        local_size,
        base_save_dir
    )

def aplicar_filtros():
    #Aplicar filtro 3x3
    aplicar_todos_kernels([f.filtro_mean,f.filtro_mean,f.filtro_mean,f.filtro_mean,f.filtro_mean,[f.filtro_meanX,f.filtro_meanY],[f.filtro_meanX,f.filtro_meanY],],"FILTRO3X3/")
    #Aplicar filtro 5x5
    aplicar_todos_kernels([f.filtro_mean5x5,[f.filtro_mean5X5X,f.filtro_mean5X5Y],f.filtro_mean5x5,f.filtro_mean5x5,f.filtro_mean5x5,f.filtro_mean5x5,[f.filtro_mean5X5X,f.filtro_mean5X5Y]],"FILTRO5X5/")
    #Aplicar filtro 7x7
    aplicar_todos_kernels([f.filtro_mean7x7,[f.filtro_mean7x7X,f.filtro_mean7x7Y],f.filtro_mean7x7,f.filtro_mean7x7,f.filtro_mean7x7,f.filtro_mean5x5,[f.filtro_mean7x7X,f.filtro_mean7x7Y]],"FILTRO7X7/")
    #Aplicar filtro 9x9
    aplicar_todos_kernels([f.filtro_mean9x9,[f.filtro_mean9x9X,f.filtro_mean9x9Y],f.filtro_mean9x9,f.filtro_mean9x9,f.filtro_mean9x9,f.filtro_mean9x9,[f.filtro_mean9x9X,f.filtro_mean9x9Y]],"FILTRO9X9/")
    #Aplicar filtro 16x16
    aplicar_todos_kernels([f.filtro_mean16x16,[f.filtro_mean16x16X,f.filtro_mean16x16Y],f.filtro_mean16x16,f.filtro_mean16x16,f.filtro_mean16x16,f.filtro_mean16x16,[f.filtro_mean16x16X,f.filtro_mean16x16Y]],"FILTRO16X16/")

# %%
aplicar_filtros()

# %%
def filtro3x3():
    # Parámetros de los kernels y funciones
    kernels = [
        kernel.kernel_filter_color,
        kernel.kernel_filter_color_local_ineficiente,
        kernel.kernel_filter_color_local_hebra_maestra,
        kernel.kernel_filter_color_local_organizado,
        kernel.kernel_filter_color_local_organizado_junto,
        kernel.kernel_filter_color_rectangular,
        kernel.kernel_filter_color_local_rectangular
    ]
    kernels_names = [
        "kernel_filter_color",
        "kernel_filter_color_local_ineficiente",
        "kernel_filter_color_local_hebra_maestra",
        "kernel_filter_color_local_organizado",
        "kernel_filter_color_local_organizado_junto",
         "kernel_filter_color_rectangular",
        "kernel_filter_color_local_rectangular"
    ]
    funciones = [
        ff.aplicar_filtro_color,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_color_dividido,
        ff.aplicar_filtro_local_dividido
    ]
    filtro_dividido=[f.filtro_meanX,f.filtro_meanY]
    filtros=[f.filtro_mean,f.filtro_mean,f.filtro_mean,f.filtro_mean,f.filtro_mean,filtro_dividido,filtro_dividido,]
    device_type =  cl.device_type.GPU 
    local_size = (8,8)  # Cambia esto al tamaño local que desees

    # Lista de rutas de las imágenes
    # Lista de paths de imágenes
    lista_paths = [
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen64x64.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen128x128.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen640x480.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen800x600.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen720x1280.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen1920x1080.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen2160x3840.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen8000x6000.jpg")]

    # Directorio base para guardar los gráficos
    #base_save_dir = "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO3X3/"
    base_save_dir = os.path.join(path, "OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO3X3/")

    # Ejecutar el experimento
    resultados_finales = ex.experimento_kernels(
        lista_paths,
        filtros,
        kernels,
        kernels_names,
        funciones,
        device_type,
        local_size,
        base_save_dir
    )
    display(resultados_finales)

def filtro5X5():
    # Parámetros de los kernels y funciones
    kernels = [
        kernel.kernel_filter_color,
        kernel.kernel_filter_color_local_ineficiente,
        kernel.kernel_filter_color_local_hebra_maestra,
        kernel.kernel_filter_color_local_organizado,
        kernel.kernel_filter_color_local_organizado_junto,
        kernel.kernel_filter_color_rectangular,
        kernel.kernel_filter_color_local_rectangular
    ]
    kernels_names = [
        "kernel_filter_color",
        "kernel_filter_color_local_ineficiente",
        "kernel_filter_color_local_hebra_maestra",
        "kernel_filter_color_local_organizado",
        "kernel_filter_color_local_organizado_junto",
         "kernel_filter_color_rectangular",
        "kernel_filter_color_local_rectangular"
    ]
    funciones = [
        ff.aplicar_filtro_color,
        ff.aplicar_filtro_color_dividido,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local_dividido
    ]
    filtro_dividido=[f.filtro_mean5X5X,f.filtro_mean5X5Y]
    filtros=[f.filtro_mean5x5,filtro_dividido,f.filtro_mean5x5,f.filtro_mean5x5,f.filtro_mean5x5,f.filtro_mean5x5,filtro_dividido]
    device_type =  cl.device_type.GPU 
    local_size = (8,8)  # Cambia esto al tamaño local que desees

    # Lista de rutas de las imágenes
    lista_paths = [
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen64x64.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen128x128.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen640x480.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen800x600.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen720x1280.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen1920x1080.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen2160x3840.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen8000x6000.jpg")]

    # Directorio base para guardar los gráficos
    #base_save_dir = "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO3X3/"
    base_save_dir = os.path.join(path, "OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO5X5/")

    # Ejecutar el experimento
    resultados_finales = ex.experimento_kernels(
        lista_paths,
        filtros,
        kernels,
        kernels_names,
        funciones,
        device_type,
        local_size,
        base_save_dir
    )
   
def filtro7x7():
    kernels = [
        kernel.kernel_filter_color,
        kernel.kernel_filter_color_local_ineficiente,
        kernel.kernel_filter_color_local_hebra_maestra,
        kernel.kernel_filter_color_local_organizado,
        kernel.kernel_filter_color_local_organizado_junto,
        kernel.kernel_filter_color_rectangular,
        kernel.kernel_filter_color_local_rectangular
    ]
    kernels_names = [
        "kernel_filter_color",
        "kernel_filter_color_local_ineficiente",
        "kernel_filter_color_local_hebra_maestra",
        "kernel_filter_color_local_organizado",
        "kernel_filter_color_local_organizado_junto",
         "kernel_filter_color_rectangular",
        "kernel_filter_color_local_rectangular"
    ]
    funciones = [
        ff.aplicar_filtro_color,
        ff.aplicar_filtro_color_dividido,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local_dividido
    ]
    filtro_dividido=[f.filtro_mean7x7X,f.filtro_mean7x7Y]
    filtros=[f.filtro_mean7x7,filtro_dividido,f.filtro_mean7x7,f.filtro_mean7x7,f.filtro_mean7x7,f.filtro_mean5x5,filtro_dividido]
    device_type =  cl.device_type.GPU 
    local_size = (8,8)  # Cambia esto al tamaño local que desees

    # Lista de rutas de las imágenes
    lista_paths = [
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen64x64.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen128x128.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen640x480.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen800x600.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen720x1280.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen1920x1080.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen2160x3840.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen8000x6000.jpg")]

    # Directorio base para guardar los gráficos
    #base_save_dir = "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO3X3/"
    base_save_dir = os.path.join(path, "OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO7X7/")

    # Ejecutar el experimento
    resultados_finales = ex.experimento_kernels(
        lista_paths,
        filtros,
        kernels,
        kernels_names,
        funciones,
        device_type,
        local_size,
        base_save_dir
    )
    display(resultados_finales)
    
def filtro9x9():
    # Parámetros de los kernels y funciones
    kernels = [
        kernel.kernel_filter_color,
        kernel.kernel_filter_color_local_ineficiente,
        kernel.kernel_filter_color_local_hebra_maestra,
        kernel.kernel_filter_color_local_organizado,
        kernel.kernel_filter_color_local_organizado_junto,
        kernel.kernel_filter_color_rectangular,
        kernel.kernel_filter_color_local_rectangular
    ]
    kernels_names = [
        "kernel_filter_color",
        "kernel_filter_color_local_ineficiente",
        "kernel_filter_color_local_hebra_maestra",
        "kernel_filter_color_local_organizado",
        "kernel_filter_color_local_organizado_junto",
         "kernel_filter_color_rectangular",
        "kernel_filter_color_local_rectangular"
    ]
    funciones = [
        ff.aplicar_filtro_color,
        ff.aplicar_filtro_color_dividido,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local_dividido
    ]
    filtro_dividido=[f.filtro_mean9x9X,f.filtro_mean9x9Y]
    filtros=[f.filtro_mean9x9,filtro_dividido,f.filtro_mean9x9,f.filtro_mean9x9,f.filtro_mean9x9,f.filtro_mean9x9,filtro_dividido]
    device_type =  cl.device_type.GPU 
    local_size = (8,8)  # Cambia esto al tamaño local que desees

    # Lista de rutas de las imágenes
    lista_paths = [
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen64x64.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen128x128.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen640x480.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen800x600.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen720x1280.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen1920x1080.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen2160x3840.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen8000x6000.jpg")]

    # Directorio base para guardar los gráficos
    #base_save_dir = "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO3X3/"
    base_save_dir = os.path.join(path, "OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO9X9/")

    
    # Ejecutar el experimento
    resultados_finales = ex.experimento_kernels(
        lista_paths,
        filtros,
        kernels,
        kernels_names,
        funciones,
        device_type,
        local_size,
        base_save_dir
    )
    display(resultados_finales)
    # Guardar los resultados en Excel si deseas (no incluido en el ejemplo)
    # guardar_dataframes_excel(resultados_finales, resultados_finales, base_save_dir, "filtro_color", "experimento_kernels")

def filtro16x16():
    # Parámetros de los kernels y funciones
    kernels = [
        kernel.kernel_filter_color,
        kernel.kernel_filter_color_local_ineficiente,
        kernel.kernel_filter_color_local_hebra_maestra,
        kernel.kernel_filter_color_local_organizado,
        kernel.kernel_filter_color_local_organizado_junto,
        kernel.kernel_filter_color_rectangular,
        kernel.kernel_filter_color_local_rectangular
    ]
    kernels_names = [
        "kernel_filter_color",
        "kernel_filter_color_local_ineficiente",
        "kernel_filter_color_local_hebra_maestra",
        "kernel_filter_color_local_organizado",
        "kernel_filter_color_local_organizado_junto",
         "kernel_filter_color_rectangular",
        "kernel_filter_color_local_rectangular"
    ]
    funciones = [
        ff.aplicar_filtro_color,
        ff.aplicar_filtro_color_dividido,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local_dividido
    ]
    filtro_dividido=[f.filtro_mean16x16X,f.filtro_mean16x16Y]
    filtros=[f.filtro_mean16x16,filtro_dividido,f.filtro_mean16x16,f.filtro_mean16x16,f.filtro_mean16x16,f.filtro_mean16x16,filtro_dividido]
    device_type =  cl.device_type.GPU 
    local_size = (8,8)  # Cambia esto al tamaño local que desees

    # Lista de rutas de las imágenes
    lista_paths = [
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen64x64.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen128x128.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen640x480.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen800x600.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen720x1280.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen1920x1080.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen2160x3840.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen8000x6000.jpg")]

    # Directorio base para guardar los gráficos
    #base_save_dir = "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO3X3/"
    base_save_dir = os.path.join(path, "OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO16X16/")

    # Ejecutar el experimento
    resultados_finales = ex.experimento_kernels(
        lista_paths,
        filtros,
        kernels,
        kernels_names,
        funciones,
        device_type,
        local_size,
        base_save_dir
    )
    display(resultados_finales)

# %% [markdown]
# EJECUTAR FUNCIONES

# %%
filtro3x3()
filtro5X5()
filtro7x7()
filtro9x9()
filtro16x16()
# Out:
# DataFrames guardados y formateados en Excel en C:/Users/maria/OneDrive/OPENCL/RESULTADOS_PORTATIL\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO3X3/kernels\resultados.xlsx
# Gráfico guardado en C:/Users/maria/OneDrive/OPENCL/RESULTADOS_PORTATIL\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO3X3/KERNELS_tiempos_ejecucion.png
#                      kernel_filter_color  kernel_filter_color_local  \
# Image Name
# imagen64x64.jpg                 0.000098                   0.000052
# imagen128x128.jpg               0.000045                   0.000041
# imagen640x480.jpg               0.000744                   0.000750
# imagen800x600.jpg               0.001076                   0.001190
# imagen720x1280.jpg              0.001704                   0.002222
# imagen1920x1080.jpg             0.004195                   0.004053
# imagen2160x3840.jpg             0.015287                   0.016380
# imagen8000x6000.jpg             0.088181                   0.096658
#
#                      kernel_filter_color_local2  kernel_filter_color_local3  \
# Image Name
# imagen64x64.jpg                        0.000084                    0.000142
# imagen128x128.jpg                      0.000491                    0.000209
# imagen640x480.jpg                      0.001325                    0.000515
# imagen800x600.jpg                      0.002814                    0.000320
# imagen720x1280.jpg                     0.003823                    0.000722
# imagen1920x1080.jpg                    0.007681                    0.001733
# imagen2160x3840.jpg                    0.033122                    0.005312
# imagen8000x6000.jpg                    0.203777                    0.054614
#
#                      kernel_filter_color_local4  \
# Image Name
# imagen64x64.jpg                        0.000016
# imagen128x128.jpg                      0.000202
# imagen640x480.jpg                      0.000208
# imagen800x600.jpg                      0.000309
# imagen720x1280.jpg                     0.001351
# imagen1920x1080.jpg                    0.001237
# imagen2160x3840.jpg                    0.005122
# imagen8000x6000.jpg                    0.054336
#
#                      kernel_filter_color_rectangular  \
# Image Name
# imagen64x64.jpg                             0.000109
# imagen128x128.jpg                           0.000104
# imagen640x480.jpg                           0.001221
# imagen800x600.jpg                           0.000889
# imagen720x1280.jpg                          0.001738
# imagen1920x1080.jpg                         0.003205
# imagen2160x3840.jpg                         0.012735
# imagen8000x6000.jpg                         0.127954
#
#                      kernel_filter_color_local_rectangular
# Image Name
# imagen64x64.jpg                                   0.000247
# imagen128x128.jpg                                 0.000049
# imagen640x480.jpg                                 0.000908
# imagen800x600.jpg                                 0.000512
# imagen720x1280.jpg                                0.001404
# imagen1920x1080.jpg                               0.002549
# imagen2160x3840.jpg                               0.008068
# imagen8000x6000.jpg                               0.088853
# DataFrames guardados y formateados en Excel en C:/Users/maria/OneDrive/OPENCL/RESULTADOS_PORTATIL\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO5X5/kernels\resultados.xlsx
# Gráfico guardado en C:/Users/maria/OneDrive/OPENCL/RESULTADOS_PORTATIL\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO5X5/KERNELS_tiempos_ejecucion.png
# DataFrames guardados y formateados en Excel en C:/Users/maria/OneDrive/OPENCL/RESULTADOS_PORTATIL\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO7X7/kernels\resultados.xlsx
# Gráfico guardado en C:/Users/maria/OneDrive/OPENCL/RESULTADOS_PORTATIL\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO7X7/KERNELS_tiempos_ejecucion.png
#                      kernel_filter_color  kernel_filter_color_rectangular  \
# Image Name
# imagen64x64.jpg                 0.000281                         0.000254
# imagen128x128.jpg               0.000985                         0.000247
# imagen640x480.jpg               0.003058                         0.000962
# imagen800x600.jpg               0.004120                         0.001832
# imagen720x1280.jpg              0.008061                         0.002830
# imagen1920x1080.jpg             0.019678                         0.006465
# imagen2160x3840.jpg             0.074049                         0.023803
# imagen8000x6000.jpg             0.450495                         0.158180
#
#                      kernel_filter_color_local  kernel_filter_color_local2  \
# Image Name
# imagen64x64.jpg                       0.000062                    0.000415
# imagen128x128.jpg                     0.000198                    0.000242
# imagen640x480.jpg                     0.002832                    0.003104
# imagen800x600.jpg                     0.004549                    0.003516
# imagen720x1280.jpg                    0.009260                    0.007037
# imagen1920x1080.jpg                   0.018981                    0.015442
# imagen2160x3840.jpg                   0.076745                    0.063417
# imagen8000x6000.jpg                   0.439160                    0.375381
#
#                      kernel_filter_color_local3  kernel_filter_color_local4  \
# Image Name
# imagen64x64.jpg                        0.000042                    0.000030
# imagen128x128.jpg                      0.000049                    0.000036
# imagen640x480.jpg                      0.000632                    0.000796
# imagen800x600.jpg                      0.000889                    0.000572
# imagen720x1280.jpg                     0.002987                    0.001302
# imagen1920x1080.jpg                    0.004126                    0.002624
# imagen2160x3840.jpg                    0.015123                    0.010777
# imagen8000x6000.jpg                    0.109132                    0.071371
#
#                      kernel_filter_color_local_rectangular
# Image Name
# imagen64x64.jpg                                   0.000274
# imagen128x128.jpg                                 0.000395
# imagen640x480.jpg                                 0.000449
# imagen800x600.jpg                                 0.001149
# imagen720x1280.jpg                                0.001622
# imagen1920x1080.jpg                               0.002756
# imagen2160x3840.jpg                               0.010022
# imagen8000x6000.jpg                               0.088644
# DataFrames guardados y formateados en Excel en C:/Users/maria/OneDrive/OPENCL/RESULTADOS_PORTATIL\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO9X9/kernels\resultados.xlsx
# Gráfico guardado en C:/Users/maria/OneDrive/OPENCL/RESULTADOS_PORTATIL\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO9X9/KERNELS_tiempos_ejecucion.png
#                      kernel_filter_color  kernel_filter_color_rectangular  \
# Image Name
# imagen64x64.jpg                 0.000204                         0.000155
# imagen128x128.jpg               0.000247                         0.000077
# imagen640x480.jpg               0.004750                         0.001160
# imagen800x600.jpg               0.007113                         0.002333
# imagen720x1280.jpg              0.013219                         0.003513
# imagen1920x1080.jpg             0.031036                         0.008011
# imagen2160x3840.jpg             0.131181                         0.029162
# imagen8000x6000.jpg             0.702342                         0.184027
#
#                      kernel_filter_color_local  kernel_filter_color_local2  \
# Image Name
# imagen64x64.jpg                       0.000114                    0.000213
# imagen128x128.jpg                     0.000711                    0.000300
# imagen640x480.jpg                     0.005269                    0.003352
# imagen800x600.jpg                     0.007087                    0.005303
# imagen720x1280.jpg                    0.013665                    0.009832
# imagen1920x1080.jpg                   0.030315                    0.021469
# imagen2160x3840.jpg                   0.119856                    0.088837
# imagen8000x6000.jpg                   0.698175                    0.503200
#
#                      kernel_filter_color_local3  kernel_filter_color_local4  \
# Image Name
# imagen64x64.jpg                        0.000319                    0.000035
# imagen128x128.jpg                      0.000152                    0.000082
# imagen640x480.jpg                      0.000893                    0.001117
# imagen800x600.jpg                      0.001839                    0.001450
# imagen720x1280.jpg                     0.002514                    0.002652
# imagen1920x1080.jpg                    0.005362                    0.006063
# imagen2160x3840.jpg                    0.021490                    0.023021
# imagen8000x6000.jpg                    0.144066                    0.141346
#
#                      kernel_filter_color_local_rectangular
# Image Name
# imagen64x64.jpg                                   0.000221
# imagen128x128.jpg                                 0.000057
# imagen640x480.jpg                                 0.000857
# imagen800x600.jpg                                 0.002024
# imagen720x1280.jpg                                0.001331
# imagen1920x1080.jpg                               0.003605
# imagen2160x3840.jpg                               0.011834
# imagen8000x6000.jpg                               0.092918
# DataFrames guardados y formateados en Excel en C:/Users/maria/OneDrive/OPENCL/RESULTADOS_PORTATIL\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO16X16/kernels\resultados.xlsx
# Gráfico guardado en C:/Users/maria/OneDrive/OPENCL/RESULTADOS_PORTATIL\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO16X16/KERNELS_tiempos_ejecucion.png
#                      kernel_filter_color  kernel_filter_color_rectangular  \
# Image Name
# imagen64x64.jpg                 0.000339                         0.000195
# imagen128x128.jpg               0.000656                         0.000597
# imagen640x480.jpg               0.015279                         0.002398
# imagen800x600.jpg               0.022613                         0.002684
# imagen720x1280.jpg              0.040476                         0.005721
# imagen1920x1080.jpg             0.090043                         0.011749
# imagen2160x3840.jpg             0.341045                         0.048989
# imagen8000x6000.jpg             1.964750                         0.293333
#
#                      kernel_filter_color_local  kernel_filter_color_local2  \
# Image Name
# imagen64x64.jpg                       0.000262                    0.000452
# imagen128x128.jpg                     0.000783                    0.000474
# imagen640x480.jpg                     0.015149                    0.006464
# imagen800x600.jpg                     0.019453                    0.010047
# imagen720x1280.jpg                    0.040213                    0.018223
# imagen1920x1080.jpg                   0.089212                    0.042507
# imagen2160x3840.jpg                   0.342826                    0.175997
# imagen8000x6000.jpg                   1.885627                    1.017102
#
#                      kernel_filter_color_local3  kernel_filter_color_local4  \
# Image Name
# imagen64x64.jpg                        0.000090                    0.000076
# imagen128x128.jpg                      0.000385                    0.000357
# imagen640x480.jpg                      0.002453                    0.002331
# imagen800x600.jpg                      0.004004                    0.004253
# imagen720x1280.jpg                     0.008179                    0.007671
# imagen1920x1080.jpg                    0.015781                    0.016628
# imagen2160x3840.jpg                    0.066653                    0.068359
# imagen8000x6000.jpg                    0.404041                    0.395278
#
#                      kernel_filter_color_local_rectangular
# Image Name
# imagen64x64.jpg                                   0.000250
# imagen128x128.jpg                                 0.000057
# imagen640x480.jpg                                 0.000954
# imagen800x600.jpg                                 0.001538
# imagen720x1280.jpg                                0.001968
# imagen1920x1080.jpg                               0.004033
# imagen2160x3840.jpg                               0.016448
# imagen8000x6000.jpg                               0.112623
