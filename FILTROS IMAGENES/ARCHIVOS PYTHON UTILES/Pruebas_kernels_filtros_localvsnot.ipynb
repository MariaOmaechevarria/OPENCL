# %% [markdown]
# EXPERIMENTO:Comparar kernels para distintos filtros con un local size fijado
#
# OBJETIVO: Determinar el mejor kernel
#
# OUTPUT: Para cada filtro una tabla con los tiempos de ejecucion y un grafico
#
# DONDE: EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS UNA CARPETA PARA CADA TAMAÑO DE FILTRO

# %% [markdown]
# Instalar pyopencl

# %%
pip install pyopencl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyopencl in c:\users\eevee\appdata\roaming\python\python311\site-packages (2024.2.7)
# Requirement already satisfied: numpy in c:\program files\python311\lib\site-packages (from pyopencl) (1.23.4)
# Requirement already satisfied: platformdirs>=2.2.0 in c:\users\eevee\appdata\roaming\python\python311\site-packages (from pyopencl) (4.3.6)
# Requirement already satisfied: pytools>=2024.1.5 in c:\users\eevee\appdata\roaming\python\python311\site-packages (from pyopencl) (2024.1.14)
# Requirement already satisfied: typing-extensions>=4 in c:\users\eevee\appdata\roaming\python\python311\site-packages (from pytools>=2024.1.5->pyopencl) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# LIBRERIAS

# %%
import pyopencl as cl
import numpy as np
import pandas as pd
import os
from PIL import Image, ImageFilter
from collections import defaultdict

# %% [markdown]
# IMPORTAR ARCHIVOS Y FUNCIONES

# %%
import funciones_filtros as ff
import kernels_filtros_imagenes as kernel
import determinar_mejor_local_size as mejor
import filtros as f
import experimento_filtros as ex

# %% [markdown]
# VALORES A ADAPTAR SEGUN EL DISPOSITIVO

# %%
'''

 # Datos GPU
compute_units = 96
processing_elements = 8

#RUTA DE ARCHIVOS
path=path="C:/Users/maria/OneDrive/OPENCL/RESULTADOS_PORTATIL" 


'''

path="C:/Users/Eevee"
# Datos GPU
compute_units = 82   #Adaptar según la GPU
processing_elements = 128

# %% [markdown]
# FUNCIONES A APLICAR, UNA POR CADA TAMAÑO DE FILTRO

# %%
def filtro3x3():
    # Parámetros de los kernels y funciones
    kernels = [
        kernel.kernel_filter_color,
        kernel.kernel_filter_color_local,
        kernel.kernel_filter_color_local2,
        kernel.kernel_filter_color_local3,
        kernel.kernel_filter_color_local4,
        kernel.kernel_filter_color_rectangular,
        kernel.kernel_filter_color_local_rectangular
    ]
    kernels_names = [
        "kernel_filter_color",
        "kernel_filter_color_local",
        "kernel_filter_color_local2",
        "kernel_filter_color_local3",
        "kernel_filter_color_local4",
         "kernel_filter_color_rectangular",
        "kernel_filter_color_local_rectangular"
    ]
    funciones = [
        ff.aplicar_filtro_color,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_color_dividido,
        ff.aplicar_filtro_local_dividido
    ]
    filtro_dividido=[f.filtro_meanX,f.filtro_meanY]
    filtros=[f.filtro_mean,f.filtro_mean,f.filtro_mean,f.filtro_mean,f.filtro_mean,filtro_dividido,filtro_dividido,]
    device_type =  cl.device_type.GPU 
    local_size = (8,8)  # Cambia esto al tamaño local que desees

    # Lista de rutas de las imágenes
    # Lista de paths de imágenes
    lista_paths = [
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen64x64.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen128x128.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen640x480.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen800x600.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen720x1280.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen1920x1080.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen2160x3840.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen8000x6000.jpg")]

    # Directorio base para guardar los gráficos
    #base_save_dir = "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO3X3/"
    base_save_dir = os.path.join(path, "OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO3X3/")

    # Ejecutar el experimento
    resultados_finales = ex.experimento_kernels(
        lista_paths,
        filtros,
        kernels,
        kernels_names,
        funciones,
        device_type,
        local_size,
        base_save_dir
    )
    display(resultados_finales)

def filtro5X5():
    # Parámetros de los kernels y funciones
    kernels = [
        kernel.kernel_filter_color,
        kernel.kernel_filter_color_rectangular,
        kernel.kernel_filter_color_local,
        kernel.kernel_filter_color_local2,
        kernel.kernel_filter_color_local3,
        kernel.kernel_filter_color_local4,
        kernel.kernel_filter_color_local_rectangular
    ]
    kernels_names = [
        "kernel_filter_color",
        "kernel_filter_color_rectangular",
        "kernel_filter_color_local",
        "kernel_filter_color_local2",
        "kernel_filter_color_local3",
        "kernel_filter_color_local4",
        "kernel_filter_color_local_rectangular"
    ]
    funciones = [
        ff.aplicar_filtro_color,
        ff.aplicar_filtro_color_dividido,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local_dividido
    ]
    filtro_dividido=[f.filtro_mean5X5X,f.filtro_mean5X5Y]
    filtros=[f.filtro_mean5x5,filtro_dividido,f.filtro_mean5x5,f.filtro_mean5x5,f.filtro_mean5x5,f.filtro_mean5x5,filtro_dividido]
    device_type =  cl.device_type.GPU 
    local_size = (8,8)  # Cambia esto al tamaño local que desees

    # Lista de rutas de las imágenes
    lista_paths = [
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen64x64.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen128x128.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen640x480.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen800x600.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen720x1280.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen1920x1080.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen2160x3840.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen8000x6000.jpg")]

    # Directorio base para guardar los gráficos
    #base_save_dir = "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO3X3/"
    base_save_dir = os.path.join(path, "OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO5X5/")

    # Ejecutar el experimento
    resultados_finales = ex.experimento_kernels(
        lista_paths,
        filtros,
        kernels,
        kernels_names,
        funciones,
        device_type,
        local_size,
        base_save_dir
    )
   
def filtro7x7():
    kernels = [
        kernel.kernel_filter_color,
        kernel.kernel_filter_color_rectangular,
        kernel.kernel_filter_color_local,
        kernel.kernel_filter_color_local2,
        kernel.kernel_filter_color_local3,
        kernel.kernel_filter_color_local4,
        kernel.kernel_filter_color_local_rectangular
    ]
    kernels_names = [
        "kernel_filter_color",
        "kernel_filter_color_rectangular",
        "kernel_filter_color_local",
        "kernel_filter_color_local2",
        "kernel_filter_color_local3",
        "kernel_filter_color_local4",
        "kernel_filter_color_local_rectangular"
    ]
    funciones = [
        ff.aplicar_filtro_color,
        ff.aplicar_filtro_color_dividido,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local_dividido
    ]
    filtro_dividido=[f.filtro_mean7x7X,f.filtro_mean7x7Y]
    filtros=[f.filtro_mean7x7,filtro_dividido,f.filtro_mean7x7,f.filtro_mean7x7,f.filtro_mean7x7,f.filtro_mean5x5,filtro_dividido]
    device_type =  cl.device_type.GPU 
    local_size = (8,8)  # Cambia esto al tamaño local que desees

    # Lista de rutas de las imágenes
    lista_paths = [
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen64x64.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen128x128.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen640x480.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen800x600.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen720x1280.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen1920x1080.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen2160x3840.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen8000x6000.jpg")]

    # Directorio base para guardar los gráficos
    #base_save_dir = "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO3X3/"
    base_save_dir = os.path.join(path, "OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO7X7/")

    # Ejecutar el experimento
    resultados_finales = ex.experimento_kernels(
        lista_paths,
        filtros,
        kernels,
        kernels_names,
        funciones,
        device_type,
        local_size,
        base_save_dir
    )
    display(resultados_finales)
    
def filtro9x9():
    # Parámetros de los kernels y funciones
    kernels = [
        kernel.kernel_filter_color,
        kernel.kernel_filter_color_rectangular,
        kernel.kernel_filter_color_local,
        kernel.kernel_filter_color_local2,
        kernel.kernel_filter_color_local3,
        kernel.kernel_filter_color_local4,
        kernel.kernel_filter_color_local_rectangular
    ]
    kernels_names = [
        "kernel_filter_color",
        "kernel_filter_color_rectangular",
        "kernel_filter_color_local",
        "kernel_filter_color_local2",
        "kernel_filter_color_local3",
        "kernel_filter_color_local4",
        "kernel_filter_color_local_rectangular"
    ]
    funciones = [
        ff.aplicar_filtro_color,
        ff.aplicar_filtro_color_dividido,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local_dividido
    ]
    filtro_dividido=[f.filtro_mean9x9X,f.filtro_mean9x9Y]
    filtros=[f.filtro_mean9x9,filtro_dividido,f.filtro_mean9x9,f.filtro_mean9x9,f.filtro_mean9x9,f.filtro_mean9x9,filtro_dividido]
    device_type =  cl.device_type.GPU 
    local_size = (8,8)  # Cambia esto al tamaño local que desees

    # Lista de rutas de las imágenes
    lista_paths = [
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen64x64.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen128x128.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen640x480.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen800x600.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen720x1280.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen1920x1080.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen2160x3840.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen8000x6000.jpg")]

    # Directorio base para guardar los gráficos
    #base_save_dir = "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO3X3/"
    base_save_dir = os.path.join(path, "OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO9X9/")

    
    # Ejecutar el experimento
    resultados_finales = ex.experimento_kernels(
        lista_paths,
        filtros,
        kernels,
        kernels_names,
        funciones,
        device_type,
        local_size,
        base_save_dir
    )
    display(resultados_finales)
    # Guardar los resultados en Excel si deseas (no incluido en el ejemplo)
    # guardar_dataframes_excel(resultados_finales, resultados_finales, base_save_dir, "filtro_color", "experimento_kernels")

def filtro16x16():
    # Parámetros de los kernels y funciones
    kernels = [
        kernel.kernel_filter_color,
        kernel.kernel_filter_color_rectangular,
        kernel.kernel_filter_color_local,
        kernel.kernel_filter_color_local2,
        kernel.kernel_filter_color_local3,
        kernel.kernel_filter_color_local4,
        kernel.kernel_filter_color_local_rectangular
    ]
    kernels_names = [
        "kernel_filter_color",
        "kernel_filter_color_rectangular",
        "kernel_filter_color_local",
        "kernel_filter_color_local2",
        "kernel_filter_color_local3",
        "kernel_filter_color_local4",
        "kernel_filter_color_local_rectangular"
    ]
    funciones = [
        ff.aplicar_filtro_color,
        ff.aplicar_filtro_color_dividido,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local_dividido
    ]
    filtro_dividido=[f.filtro_mean16x16X,f.filtro_mean16x16Y]
    filtros=[f.filtro_mean16x16,filtro_dividido,f.filtro_mean16x16,f.filtro_mean16x16,f.filtro_mean16x16,f.filtro_mean16x16,filtro_dividido]
    device_type =  cl.device_type.GPU 
    local_size = (8,8)  # Cambia esto al tamaño local que desees

    # Lista de rutas de las imágenes
    lista_paths = [
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen64x64.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen128x128.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen640x480.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen800x600.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen720x1280.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen1920x1080.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen2160x3840.jpg"),
       os.path.join(path, "OPENCL/FILTROS IMAGENES/IMAGENES/imagen8000x6000.jpg")]

    # Directorio base para guardar los gráficos
    #base_save_dir = "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO3X3/"
    base_save_dir = os.path.join(path, "OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO16X16/")

    # Ejecutar el experimento
    resultados_finales = ex.experimento_kernels(
        lista_paths,
        filtros,
        kernels,
        kernels_names,
        funciones,
        device_type,
        local_size,
        base_save_dir
    )
    display(resultados_finales)

# %% [markdown]
# EJECUTAR FUNCIONES

# %%
filtro3x3()
filtro5X5()
filtro7x7()
filtro9x9()
filtro16x16()
# Out:
# C:\Users\Eevee\AppData\Roaming\Python\Python311\site-packages\pyopencl\__init__.py:519: CompilerWarning: Non-empty compiler output encountered. Set the environment variable PYOPENCL_COMPILER_OUTPUT=1 to see more.
#   lambda: self._prg.build(options_bytes, devices),
# C:\Users\Eevee\AppData\Roaming\Python\Python311\site-packages\pyopencl\__init__.py:519: CompilerWarning: Non-empty compiler output encountered. Set the environment variable PYOPENCL_COMPILER_OUTPUT=1 to see more.
#   lambda: self._prg.build(options_bytes, devices),
# C:\Users\Eevee\AppData\Roaming\Python\Python311\site-packages\pyopencl\__init__.py:519: CompilerWarning: Non-empty compiler output encountered. Set the environment variable PYOPENCL_COMPILER_OUTPUT=1 to see more.
#   lambda: self._prg.build(options_bytes, devices),
# DataFrames guardados y formateados en Excel en C:/Users/Eevee\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO3X3/kernels\resultados.xlsx
# Gráfico guardado en C:/Users/Eevee\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO3X3/KERNELS_tiempos_ejecucion.png
#                      kernel_filter_color  kernel_filter_color_local  \
# Image Name
# imagen64x64.jpg                 0.000007                   0.000006
# imagen128x128.jpg               0.000007                   0.000008
# imagen640x480.jpg               0.000026                   0.000036
# imagen800x600.jpg               0.000023                   0.000031
# imagen720x1280.jpg              0.000040                   0.000053
# imagen1920x1080.jpg             0.000135                   0.000197
# imagen2160x3840.jpg             0.000280                   0.000402
# imagen8000x6000.jpg             0.001879                   0.003068
#
#                      kernel_filter_color_local2  kernel_filter_color_local3  \
# Image Name
# imagen64x64.jpg                        0.000012                    0.000007
# imagen128x128.jpg                      0.000014                    0.000007
# imagen640x480.jpg                      0.000078                    0.000018
# imagen800x600.jpg                      0.000114                    0.000022
# imagen720x1280.jpg                     0.000213                    0.000039
# imagen1920x1080.jpg                    0.000473                    0.000087
# imagen2160x3840.jpg                    0.002184                    0.000281
# imagen8000x6000.jpg                    0.011572                    0.001649
#
#                      kernel_filter_color_local4  \
# Image Name
# imagen64x64.jpg                        0.000007
# imagen128x128.jpg                      0.000007
# imagen640x480.jpg                      0.000019
# imagen800x600.jpg                      0.000022
# imagen720x1280.jpg                     0.000038
# imagen1920x1080.jpg                    0.000087
# imagen2160x3840.jpg                    0.000281
# imagen8000x6000.jpg                    0.001649
#
#                      kernel_filter_color_rectangular  \
# Image Name
# imagen64x64.jpg                             0.000011
# imagen128x128.jpg                           0.000012
# imagen640x480.jpg                           0.000031
# imagen800x600.jpg                           0.000038
# imagen720x1280.jpg                          0.000062
# imagen1920x1080.jpg                         0.000144
# imagen2160x3840.jpg                         0.000425
# imagen8000x6000.jpg                         0.002797
#
#                      kernel_filter_color_local_rectangular
# Image Name
# imagen64x64.jpg                                   0.000011
# imagen128x128.jpg                                 0.000014
# imagen640x480.jpg                                 0.000032
# imagen800x600.jpg                                 0.000037
# imagen720x1280.jpg                                0.000062
# imagen1920x1080.jpg                               0.000134
# imagen2160x3840.jpg                               0.000402
# imagen8000x6000.jpg                               0.002503
# DataFrames guardados y formateados en Excel en C:/Users/Eevee\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO5X5/kernels\resultados.xlsx
# Gráfico guardado en C:/Users/Eevee\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO5X5/KERNELS_tiempos_ejecucion.png
# DataFrames guardados y formateados en Excel en C:/Users/Eevee\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO7X7/kernels\resultados.xlsx
# Gráfico guardado en C:/Users/Eevee\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO7X7/KERNELS_tiempos_ejecucion.png
#                      kernel_filter_color  kernel_filter_color_rectangular  \
# Image Name
# imagen64x64.jpg                 0.000008                         0.000013
# imagen128x128.jpg               0.000011                         0.000014
# imagen640x480.jpg               0.000092                         0.000045
# imagen800x600.jpg               0.000068                         0.000041
# imagen720x1280.jpg              0.000140                         0.000075
# imagen1920x1080.jpg             0.000576                         0.000225
# imagen2160x3840.jpg             0.001067                         0.000520
# imagen8000x6000.jpg             0.007306                         0.003457
#
#                      kernel_filter_color_local  kernel_filter_color_local2  \
# Image Name
# imagen64x64.jpg                       0.000013                    0.000019
# imagen128x128.jpg                     0.000015                    0.000022
# imagen640x480.jpg                     0.000155                    0.000161
# imagen800x600.jpg                     0.000140                    0.000241
# imagen720x1280.jpg                    0.000238                    0.000452
# imagen1920x1080.jpg                   0.000992                    0.001005
# imagen2160x3840.jpg                   0.002052                    0.003965
# imagen8000x6000.jpg                   0.018129                    0.023859
#
#                      kernel_filter_color_local3  kernel_filter_color_local4  \
# Image Name
# imagen64x64.jpg                        0.000009                    0.000007
# imagen128x128.jpg                      0.000009                    0.000008
# imagen640x480.jpg                      0.000049                    0.000026
# imagen800x600.jpg                      0.000064                    0.000032
# imagen720x1280.jpg                     0.000116                    0.000055
# imagen1920x1080.jpg                    0.000283                    0.000133
# imagen2160x3840.jpg                    0.000976                    0.000433
# imagen8000x6000.jpg                    0.006254                    0.002627
#
#                      kernel_filter_color_local_rectangular
# Image Name
# imagen64x64.jpg                                   0.000013
# imagen128x128.jpg                                 0.000014
# imagen640x480.jpg                                 0.000037
# imagen800x600.jpg                                 0.000044
# imagen720x1280.jpg                                0.000072
# imagen1920x1080.jpg                               0.000170
# imagen2160x3840.jpg                               0.000495
# imagen8000x6000.jpg                               0.003301
# DataFrames guardados y formateados en Excel en C:/Users/Eevee\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO9X9/kernels\resultados.xlsx
# Gráfico guardado en C:/Users/Eevee\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO9X9/KERNELS_tiempos_ejecucion.png
#                      kernel_filter_color  kernel_filter_color_rectangular  \
# Image Name
# imagen64x64.jpg                 0.000010                         0.000013
# imagen128x128.jpg               0.000014                         0.000015
# imagen640x480.jpg               0.000142                         0.000051
# imagen800x600.jpg               0.000105                         0.000047
# imagen720x1280.jpg              0.000222                         0.000085
# imagen1920x1080.jpg             0.000926                         0.000270
# imagen2160x3840.jpg             0.001740                         0.000602
# imagen8000x6000.jpg             0.011999                         0.004028
#
#                      kernel_filter_color_local  kernel_filter_color_local2  \
# Image Name
# imagen64x64.jpg                       0.000015                    0.000025
# imagen128x128.jpg                     0.000019                    0.000027
# imagen640x480.jpg                     0.000193                    0.000214
# imagen800x600.jpg                     0.000174                    0.000324
# imagen720x1280.jpg                    0.000326                    0.001222
# imagen1920x1080.jpg                   0.001220                    0.001359
# imagen2160x3840.jpg                   0.002830                    0.005383
# imagen8000x6000.jpg                   0.020298                    0.032817
#
#                      kernel_filter_color_local3  kernel_filter_color_local4  \
# Image Name
# imagen64x64.jpg                        0.000009                    0.000008
# imagen128x128.jpg                      0.000010                    0.000010
# imagen640x480.jpg                      0.000050                    0.000050
# imagen800x600.jpg                      0.000071                    0.000071
# imagen720x1280.jpg                     0.000127                    0.000126
# imagen1920x1080.jpg                    0.000286                    0.000287
# imagen2160x3840.jpg                    0.001069                    0.001069
# imagen8000x6000.jpg                    0.006226                    0.006212
#
#                      kernel_filter_color_local_rectangular
# Image Name
# imagen64x64.jpg                                   0.000013
# imagen128x128.jpg                                 0.000013
# imagen640x480.jpg                                 0.000037
# imagen800x600.jpg                                 0.000043
# imagen720x1280.jpg                                0.000072
# imagen1920x1080.jpg                               0.000162
# imagen2160x3840.jpg                               0.000500
# imagen8000x6000.jpg                               0.004122
# DataFrames guardados y formateados en Excel en C:/Users/Eevee\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO16X16/kernels\resultados.xlsx
# Gráfico guardado en C:/Users/Eevee\OPENCL/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO16X16/KERNELS_tiempos_ejecucion.png
#                      kernel_filter_color  kernel_filter_color_rectangular  \
# Image Name
# imagen64x64.jpg                 0.000017                         0.000014
# imagen128x128.jpg               0.000028                         0.000015
# imagen640x480.jpg               0.000375                         0.000071
# imagen800x600.jpg               0.000264                         0.000062
# imagen720x1280.jpg              0.000572                         0.000116
# imagen1920x1080.jpg             0.002495                         0.000403
# imagen2160x3840.jpg             0.004604                         0.000838
# imagen8000x6000.jpg             0.033048                         0.005742
#
#                      kernel_filter_color_local  kernel_filter_color_local2  \
# Image Name
# imagen64x64.jpg                       0.000034                    0.000036
# imagen128x128.jpg                     0.000049                    0.000040
# imagen640x480.jpg                     0.000710                    0.000375
# imagen800x600.jpg                     0.000666                    0.000569
# imagen720x1280.jpg                    0.001145                    0.001078
# imagen1920x1080.jpg                   0.004694                    0.002413
# imagen2160x3840.jpg                   0.011989                    0.009592
# imagen8000x6000.jpg                   0.087312                    0.069828
#
#                      kernel_filter_color_local3  kernel_filter_color_local4  \
# Image Name
# imagen64x64.jpg                        0.000013                    0.000014
# imagen128x128.jpg                      0.000019                    0.000018
# imagen640x480.jpg                      0.000209                    0.000210
# imagen800x600.jpg                      0.000308                    0.000308
# imagen720x1280.jpg                     0.000588                    0.000587
# imagen1920x1080.jpg                    0.001381                    0.001381
# imagen2160x3840.jpg                    0.005272                    0.005273
# imagen8000x6000.jpg                    0.033243                    0.034340
#
#                      kernel_filter_color_local_rectangular
# Image Name
# imagen64x64.jpg                                   0.000015
# imagen128x128.jpg                                 0.000014
# imagen640x480.jpg                                 0.000052
# imagen800x600.jpg                                 0.000066
# imagen720x1280.jpg                                0.000111
# imagen1920x1080.jpg                               0.000269
# imagen2160x3840.jpg                               0.000856
# imagen8000x6000.jpg                               0.005640
