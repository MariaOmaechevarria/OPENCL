# %%
pip install pyopencl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyopencl as cl
import numpy as np
import pandas as pd
import os
from PIL import Image, ImageFilter
from collections import defaultdict

# %%
import funciones_filtros as ff
import kernels_filtros_imagenes as kernel
import determinar_mejor_local_size as mejor
import filtros as f
import experimento_filtros as ex

# %%
def filtro3x3():
    # Parámetros de los kernels y funciones
    kernels = [
        kernel.kernel_filter_color,
        kernel.kernel_filter_color_local,
        kernel.kernel_filter_color_local2,
        kernel.kernel_filter_color_local3,
        kernel.kernel_filter_color_local4,
        kernel.kernel_filter_color_rectangular,
        kernel.kernel_filter_color_local_rectangular
    ]
    kernels_names = [
        "kernel_filter_color",
        "kernel_filter_color_local",
        "kernel_filter_color_local2",
        "kernel_filter_color_local3",
        "kernel_filter_color_local4",
         "kernel_filter_color_rectangular",
        "kernel_filter_color_local_rectangular"
    ]
    funciones = [
        ff.aplicar_filtro_color,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_color_dividido,
        ff.aplicar_filtro_local_dividido
    ]
    filtro_dividido=[f.filtro_meanX,f.filtro_meanY]
    filtros=[f.filtro_mean,f.filtro_mean,f.filtro_mean,f.filtro_mean,f.filtro_mean,filtro_dividido,filtro_dividido,]
    device_type =  cl.device_type.GPU 
    local_size = (8,8)  # Cambia esto al tamaño local que desees

    # Lista de rutas de las imágenes
    lista_paths = [
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen64x64.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen128x128.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen640x480.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen800x600.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen720x1280.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen1920x1080.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen2160x3840.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen8000x6000.jpg"
    ]

    # Directorio base para guardar los gráficos
    base_save_dir = "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO3X3/"

    image_names = [path.split('/')[-1] for path in lista_paths]

    # Ejecutar el experimento
    resultados_finales = ex.experimento_kernels(
        lista_paths,
        filtros,
        kernels,
        kernels_names,
        funciones,
        device_type,
        local_size,
        base_save_dir
    )
    display(resultados_finales)
    # Guardar los resultados en Excel si deseas (no incluido en el ejemplo)
    # guardar_dataframes_excel(resultados_finales, resultados_finales, base_save_dir, "filtro_color", "experimento_kernels")

def filtro5X5():
    # Parámetros de los kernels y funciones
    kernels = [
        kernel.kernel_filter_color,
        kernel.kernel_filter_color_rectangular,
        kernel.kernel_filter_color_local,
        kernel.kernel_filter_color_local2,
        kernel.kernel_filter_color_local3,
        kernel.kernel_filter_color_local4,
        kernel.kernel_filter_color_local_rectangular
    ]
    kernels_names = [
        "kernel_filter_color",
        "kernel_filter_color_rectangular",
        "kernel_filter_color_local",
        "kernel_filter_color_local2",
        "kernel_filter_color_local3",
        "kernel_filter_color_local4",
        "kernel_filter_color_local_rectangular"
    ]
    funciones = [
        ff.aplicar_filtro_color,
        ff.aplicar_filtro_color_dividido,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local_dividido
    ]
    filtro_dividido=[f.filtro_mean5X5X,f.filtro_mean5X5Y]
    filtros=[f.filtro_mean5x5,filtro_dividido,f.filtro_mean5x5,f.filtro_mean5x5,f.filtro_mean5x5,f.filtro_mean5x5,filtro_dividido]
    device_type =  cl.device_type.GPU 
    local_size = (8,8)  # Cambia esto al tamaño local que desees

    # Lista de rutas de las imágenes
    lista_paths = [
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen64x64.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen128x128.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen640x480.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen800x600.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen720x1280.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen1920x1080.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen2160x3840.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen8000x6000.jpg"
    ]

    # Directorio base para guardar los gráficos
    base_save_dir = "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO5X5/"

    image_names = [path.split('/')[-1] for path in lista_paths]

    # Ejecutar el experimento
    resultados_finales = ex.experimento_kernels(
        lista_paths,
        filtros,
        kernels,
        kernels_names,
        funciones,
        device_type,
        local_size,
        base_save_dir
    )
    display(resultados_finales)
    # Guardar los resultados en Excel si deseas (no incluido en el ejemplo)
    # guardar_dataframes_excel(resultados_finales, resultados_finales, base_save_dir, "filtro_color", "experimento_kernels")

def filtro7x7():
    kernels = [
        kernel.kernel_filter_color,
        kernel.kernel_filter_color_rectangular,
        kernel.kernel_filter_color_local,
        kernel.kernel_filter_color_local2,
        kernel.kernel_filter_color_local3,
        kernel.kernel_filter_color_local4,
        kernel.kernel_filter_color_local_rectangular
    ]
    kernels_names = [
        "kernel_filter_color",
        "kernel_filter_color_rectangular",
        "kernel_filter_color_local",
        "kernel_filter_color_local2",
        "kernel_filter_color_local3",
        "kernel_filter_color_local4",
        "kernel_filter_color_local_rectangular"
    ]
    funciones = [
        ff.aplicar_filtro_color,
        ff.aplicar_filtro_color_dividido,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local_dividido
    ]
    filtro_dividido=[f.filtro_mean7x7X,f.filtro_mean7x7Y]
    filtros=[f.filtro_mean7x7,filtro_dividido,f.filtro_mean7x7,f.filtro_mean7x7,f.filtro_mean7x7,f.filtro_mean5x5,filtro_dividido]
    device_type =  cl.device_type.GPU 
    local_size = (8,8)  # Cambia esto al tamaño local que desees

    # Lista de rutas de las imágenes
    lista_paths = [
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen64x64.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen128x128.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen640x480.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen800x600.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen720x1280.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen1920x1080.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen2160x3840.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen8000x6000.jpg"
    ]

    # Directorio base para guardar los gráficos
    base_save_dir = "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO7X7/"

    image_names = [path.split('/')[-1] for path in lista_paths]

    # Ejecutar el experimento
    resultados_finales = ex.experimento_kernels(
        lista_paths,
        filtros,
        kernels,
        kernels_names,
        funciones,
        device_type,
        local_size,
        base_save_dir
    )
    display(resultados_finales)
    # Guardar los resultados en Excel si deseas (no incluido en el ejemplo)
    # guardar_dataframes_excel(resultados_finales, resultados_finales, base_save_dir, "filtro_color", "experimento_kernels")

def filtro9x9():
    # Parámetros de los kernels y funciones
    kernels = [
        kernel.kernel_filter_color,
        kernel.kernel_filter_color_rectangular,
        kernel.kernel_filter_color_local,
        kernel.kernel_filter_color_local2,
        kernel.kernel_filter_color_local3,
        kernel.kernel_filter_color_local4,
        kernel.kernel_filter_color_local_rectangular
    ]
    kernels_names = [
        "kernel_filter_color",
        "kernel_filter_color_rectangular",
        "kernel_filter_color_local",
        "kernel_filter_color_local2",
        "kernel_filter_color_local3",
        "kernel_filter_color_local4",
        "kernel_filter_color_local_rectangular"
    ]
    funciones = [
        ff.aplicar_filtro_color,
        ff.aplicar_filtro_color_dividido,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local_dividido
    ]
    filtro_dividido=[f.filtro_mean9x9X,f.filtro_mean9x9Y]
    filtros=[f.filtro_mean9x9,filtro_dividido,f.filtro_mean9x9,f.filtro_mean9x9,f.filtro_mean9x9,f.filtro_mean9x9,filtro_dividido]
    device_type =  cl.device_type.GPU 
    local_size = (8,8)  # Cambia esto al tamaño local que desees

    # Lista de rutas de las imágenes
    lista_paths = [
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen64x64.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen128x128.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen640x480.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen800x600.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen720x1280.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen1920x1080.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen2160x3840.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen8000x6000.jpg"
    ]

    # Directorio base para guardar los gráficos
    base_save_dir = "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO9X9/"

    image_names = [path.split('/')[-1] for path in lista_paths]

    # Ejecutar el experimento
    resultados_finales = ex.experimento_kernels(
        lista_paths,
        filtros,
        kernels,
        kernels_names,
        funciones,
        device_type,
        local_size,
        base_save_dir
    )
    display(resultados_finales)
    # Guardar los resultados en Excel si deseas (no incluido en el ejemplo)
    # guardar_dataframes_excel(resultados_finales, resultados_finales, base_save_dir, "filtro_color", "experimento_kernels")

def filtro16x16():
    # Parámetros de los kernels y funciones
    kernels = [
        kernel.kernel_filter_color,
        kernel.kernel_filter_color_rectangular,
        kernel.kernel_filter_color_local,
        kernel.kernel_filter_color_local2,
        kernel.kernel_filter_color_local3,
        kernel.kernel_filter_color_local4,
        kernel.kernel_filter_color_local_rectangular
    ]
    kernels_names = [
        "kernel_filter_color",
        "kernel_filter_color_rectangular",
        "kernel_filter_color_local",
        "kernel_filter_color_local2",
        "kernel_filter_color_local3",
        "kernel_filter_color_local4",
        "kernel_filter_color_local_rectangular"
    ]
    funciones = [
        ff.aplicar_filtro_color,
        ff.aplicar_filtro_color_dividido,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local,
        ff.aplicar_filtro_local_dividido
    ]
    filtro_dividido=[f.filtro_mean16x16X,f.filtro_mean16x16Y]
    filtros=[f.filtro_mean16x16,filtro_dividido,f.filtro_mean16x16,f.filtro_mean16x16,f.filtro_mean16x16,f.filtro_mean16x16,filtro_dividido]
    device_type =  cl.device_type.GPU 
    local_size = (8,8)  # Cambia esto al tamaño local que desees

    # Lista de rutas de las imágenes
    lista_paths = [
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen64x64.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen128x128.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen640x480.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen800x600.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen720x1280.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen1920x1080.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen2160x3840.jpg",
        "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/IMAGENES/imagen8000x6000.jpg"
    ]

    # Directorio base para guardar los gráficos
    base_save_dir = "C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO16X16/"

    image_names = [path.split('/')[-1] for path in lista_paths]

    # Ejecutar el experimento
    resultados_finales = ex.experimento_kernels(
        lista_paths,
        filtros,
        kernels,
        kernels_names,
        funciones,
        device_type,
        local_size,
        base_save_dir
    )
    display(resultados_finales)
    # Guardar los resultados en Excel si deseas (no incluido en el ejemplo)
    # guardar_dataframes_excel(resultados_finales, resultados_finales, base_save_dir, "filtro_color", "experimento_kernels")

# %%
filtro3x3()
filtro5X5()
filtro7x7()
filtro9x9()
filtro16x16()
# Out:
# DataFrames guardados y formateados en Excel en C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO3X3/kernels\resultados.xlsx
# Gráfico guardado en C:/Users/Eevee/Documents/OPENCL TFG IMP/FILTROS IMAGENES/EXPERIMENTOS/RESULTADOS/COMPARACION_KERNELS/FILTRO3X3/KERNELS_tiempos_ejecucion.png
#                      kernel_filter_color  kernel_filter_color_local  \
# Image Name
# imagen64x64.jpg                 0.000006                   0.000007
# imagen128x128.jpg               0.000006                   0.000007
# imagen640x480.jpg               0.000026                   0.000035
# imagen800x600.jpg               0.000022                   0.000031
# imagen720x1280.jpg              0.000040                   0.000053
# imagen1920x1080.jpg             0.000134                   0.000197
# imagen2160x3840.jpg             0.000278                   0.000402
# imagen8000x6000.jpg             0.001878                   0.003068
#
# ...
